# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import time
import pickle
import napari
import numpy as np
import pandas as pd

from skimage.io import imread

import btrack
from btrack.constants import BayesianUpdates

sys.path.append('../libraries')
import input_functions as inp_f

# %%
info_file_path = r'Z:\Sonja\210910_endo_meso_52\210910_endo_meso_52_info.txt'

# %%
# read the file
info_file = open(info_file_path, 'r')
info_lines = info_file.readlines()
info_file.close()

# read info about the data frame
exp_dir,df_name = inp_f.read_df_info(info_lines)

df_dir = os.path.join(exp_dir,'df')
save_dir = df_dir

frames_to_exclude = inp_f.read_frames_2_exclude(info_lines)
frames_to_exclude = eval(frames_to_exclude)

modelPath = os.path.join(exp_dir,'code','libraries','cell_config.json')

# %% [markdown]
# ## Read in the data frame objects data

# %%
data_df = pd.read_pickle(os.path.join(df_dir,df_name))
len(data_df)
# Out:
# 223543

# %%
'''
data_df.drop(inplace=True,axis=1,columns=['track_id', 'x', 'y', 'parent', 'generation', 'root', 'accepted',
       'rejected', 'promise'])
'''

# %% [markdown]
# ## Tracking proper

# %%
n_part = 4
part_len = int(np.max(data_df.t)/n_part)

# %%
track_list = []
for n in range(n_part):
    
    #calculate boundaries
    start = n * part_len
    stop = (n+1) * part_len
    if n == (n_part - 1):
        stop = len(data_df)
        
    # calculate offset
    if n==0:
        offset = 0
    else:
        offset = np.max(data[:,0])
    
    # choose objects 
    sel_vector = [(not(x in frames_to_exclude) and (x>start) and (x<stop)) for x in data_df.t]

    objects_gen = data_df.loc[sel_vector,['label','area','centroid-1','centroid-0','major_axis_length','minor_axis_length','t']]

    objects_gen.columns=['ID', 'area', 'x', 'y', 'major_axis_length','minor_axis_length','t']
    objects_gen['z']=0
    objects_gen['label']=5
    objects_gen['prob']=0
    objects_gen['dummy']=False
    objects_gen['states']=0

    # initialise a tracker session using a context manager
    with btrack.BayesianTracker() as tracker:

        # configure the tracker using a config file
        tracker.configure_from_file(modelPath)

        # approximate
        tracker.update_method = BayesianUpdates.APPROXIMATE
        tracker.max_search_radius = 200

        # append the objects to be tracked
        tracker.append(objects_gen)

        # set the volume (Z axis volume is set very large for 2D data)
        tracker.volume=((0, data_df.size_x[0]), (0, data_df.size_y[0]), (-1e5, 1e5))

        # track them (in interactive mode)
        tracker.track_interactive(step_size=100)
        
        # generate hypotheses and run the global optimizer
        tracker.optimize()

        # optional: get the data in a format for napari
        data, properties, graph = tracker.to_napari(ndim=2)
        
    # add offset
    data[:,0] = data[:,0] + offset
    #data[:,1] = data[:,1]
        
    # collect data
    temp = pd.DataFrame(data,columns=['track_id','t','x','y'])
    temp['parent'] = properties['parent'] + offset
    temp['generation'] = properties['generation']
    temp['root'] = properties['root'] + offset
    
    track_list.append(temp)
    
trackDataAll = pd.concat(track_list,ignore_index = True)
# Out:
# [INFO][2021/12/08 12:48:18 PM] Loaded btrack: C:\Users\kmkedz\AppData\Roaming\Python\Python37\site-packages\btrack\libs\libtracker.DLL
# [INFO][2021/12/08 12:48:18 PM] btrack (v0.4.2) library imported
# [INFO][2021/12/08 12:48:18 PM] Setting max XYZ search radius to: 100
# [INFO][2021/12/08 12:48:18 PM] Starting BayesianTracker session
# [INFO][2021/12/08 12:48:18 PM] Loading configuration file: Z:\Sonja\210910_endo_meso_52\code\libraries\cell_config.json
# [INFO][2021/12/08 12:48:18 PM] Loading motion model: b'cell_motion'
# [INFO][2021/12/08 12:48:18 PM] Setting Bayesian update method to: BayesianUpdates.APPROXIMATE
# [INFO][2021/12/08 12:48:18 PM] Setting max XYZ search radius to: 200
# [INFO][2021/12/08 12:48:18 PM] Objects are of type: <class 'pandas.core.frame.DataFrame'>
# [INFO][2021/12/08 12:48:19 PM] Set volume to ((0, 2048), (0, 2048), (-100000.0, 100000.0))
# [INFO][2021/12/08 12:48:19 PM] Starting tracking...
# [INFO][2021/12/08 12:48:19 PM] Tracking objects in frames 0 to 99 (of 258)...
# [INFO][2021/12/08 12:48:22 PM]  - Timing (Bayesian updates: 16.00ms, Linking: 4.00ms)
# [INFO][2021/12/08 12:48:22 PM]  - Probabilities (Link: 0.99935, Lost: 0.53861)
# [INFO][2021/12/08 12:48:22 PM]  - Stats (Active: 712, Lost: 44738, Conflicts resolved: 8548)
# [INFO][2021/12/08 12:48:22 PM] Tracking objects in frames 100 to 199 (of 258)...
# [INFO][2021/12/08 12:48:24 PM]  - Timing (Bayesian updates: 11.00ms, Linking: 3.00ms)
# [INFO][2021/12/08 12:48:24 PM]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2021/12/08 12:48:24 PM]  - Stats (Active: 502, Lost: 75487, Conflicts resolved: 15412)
# [INFO][2021/12/08 12:48:24 PM] Tracking objects in frames 200 to 258 (of 258)...
# [INFO][2021/12/08 12:48:25 PM]  - Timing (Bayesian updates: 10.00ms, Linking: 3.00ms)
# [INFO][2021/12/08 12:48:25 PM]  - Probabilities (Link: 1.00000, Lost: 0.99998)
# [INFO][2021/12/08 12:48:25 PM] SUCCESS.
# [INFO][2021/12/08 12:48:25 PM]  - Found 16127 tracks in 258 frames (in 0.0s)
# [INFO][2021/12/08 12:48:25 PM]  - Inserted 15681 dummy objects to fill tracking gaps
# [INFO][2021/12/08 12:48:25 PM] Loading hypothesis model: cell_hypothesis
# [INFO][2021/12/08 12:48:25 PM] Calculating hypotheses (relax: True)...
# [INFO][2021/12/08 12:48:25 PM] Setting up constraints matrix for global optimisation...
# [INFO][2021/12/08 12:48:30 PM] Optimizing...
# [INFO][2021/12/08 12:52:35 PM] Optimization complete. (Solution: optimal)
# [INFO][2021/12/08 12:52:35 PM]  - Fates.FALSE_POSITIVE: 3916 (of 16127)
# [INFO][2021/12/08 12:52:35 PM]  - Fates.LINK: 8534 (of 12642)
# [INFO][2021/12/08 12:52:35 PM]  - Fates.DIVIDE: 407 (of 1388)
# [INFO][2021/12/08 12:52:35 PM]  - Fates.INITIALIZE_BORDER: 47 (of 176)
# [INFO][2021/12/08 12:52:35 PM]  - Fates.INITIALIZE_FRONT: 437 (of 686)
# [INFO][2021/12/08 12:52:35 PM]  - Fates.INITIALIZE_LAZY: 2379 (of 15265)
# [INFO][2021/12/08 12:52:35 PM]  - Fates.TERMINATE_BORDER: 60 (of 183)
# [INFO][2021/12/08 12:52:35 PM]  - Fates.TERMINATE_BACK: 319 (of 451)
# [INFO][2021/12/08 12:52:35 PM]  - Fates.TERMINATE_LAZY: 2891 (of 15493)
# [INFO][2021/12/08 12:52:35 PM]  - TOTAL: 62411 hypotheses
# [INFO][2021/12/08 12:52:35 PM] Completed optimization with 7593 tracks
# [INFO][2021/12/08 12:52:37 PM] Ending BayesianTracker session
# [INFO][2021/12/08 12:52:37 PM] Loaded btrack: C:\Users\kmkedz\AppData\Roaming\Python\Python37\site-packages\btrack\libs\libtracker.DLL
# [INFO][2021/12/08 12:52:37 PM] btrack (v0.4.2) library imported
# [INFO][2021/12/08 12:52:37 PM] Setting max XYZ search radius to: 100
# [INFO][2021/12/08 12:52:37 PM] Starting BayesianTracker session
# [INFO][2021/12/08 12:52:37 PM] Loading configuration file: Z:\Sonja\210910_endo_meso_52\code\libraries\cell_config.json
# [INFO][2021/12/08 12:52:37 PM] Loading motion model: b'cell_motion'
# [INFO][2021/12/08 12:52:37 PM] Setting Bayesian update method to: BayesianUpdates.APPROXIMATE
# [INFO][2021/12/08 12:52:37 PM] Setting max XYZ search radius to: 200
# [INFO][2021/12/08 12:52:37 PM] Objects are of type: <class 'pandas.core.frame.DataFrame'>
# [INFO][2021/12/08 12:52:39 PM] Set volume to ((0, 2048), (0, 2048), (-100000.0, 100000.0))
# [INFO][2021/12/08 12:52:39 PM] Starting tracking...
# [INFO][2021/12/08 12:52:39 PM] Tracking objects in frames 0 to 99 (of 516)...
# [INFO][2021/12/08 12:52:40 PM]  - Timing (Bayesian updates: 19.00ms, Linking: 3.00ms)
# [INFO][2021/12/08 12:52:40 PM]  - Probabilities (Link: 0.99973, Lost: 1.00000)
# [INFO][2021/12/08 12:52:40 PM]  - Stats (Active: 548, Lost: 17146, Conflicts resolved: 5244)
# [INFO][2021/12/08 12:52:40 PM] Tracking objects in frames 100 to 199 (of 516)...
# [INFO][2021/12/08 12:52:44 PM]  - Timing (Bayesian updates: 42.00ms, Linking: 7.00ms)
# [INFO][2021/12/08 12:52:44 PM]  - Probabilities (Link: 0.28061, Lost: 0.90382)
# [INFO][2021/12/08 12:52:44 PM]  - Stats (Active: 833, Lost: 41585, Conflicts resolved: 13623)
# [INFO][2021/12/08 12:52:44 PM] Tracking objects in frames 200 to 299 (of 516)...
# [INFO][2021/12/08 12:52:46 PM]  - Timing (Bayesian updates: 37.00ms, Linking: 6.00ms)
# [INFO][2021/12/08 12:52:46 PM]  - Probabilities (Link: 1.00000, Lost: 0.85627)
# [INFO][2021/12/08 12:52:46 PM] SUCCESS.
# [INFO][2021/12/08 12:52:46 PM]  - Found 12685 tracks in 516 frames (in 0.0s)
# [INFO][2021/12/08 12:52:46 PM]  - Inserted 13051 dummy objects to fill tracking gaps
# [INFO][2021/12/08 12:52:46 PM] Loading hypothesis model: cell_hypothesis
# [INFO][2021/12/08 12:52:46 PM] Calculating hypotheses (relax: True)...
# [INFO][2021/12/08 12:52:47 PM] Setting up constraints matrix for global optimisation...
# [INFO][2021/12/08 12:52:50 PM] Optimizing...
# [INFO][2021/12/08 12:53:12 PM] Optimization complete. (Solution: optimal)
# [INFO][2021/12/08 12:53:12 PM]  - Fates.FALSE_POSITIVE: 3444 (of 12685)
# [INFO][2021/12/08 12:53:12 PM]  - Fates.LINK: 5102 (of 9580)
# [INFO][2021/12/08 12:53:12 PM]  - Fates.DIVIDE: 612 (of 2409)
# [INFO][2021/12/08 12:53:12 PM]  - Fates.INITIALIZE_BORDER: 149 (of 422)
# [INFO][2021/12/08 12:53:12 PM]  - Fates.INITIALIZE_LAZY: 2766 (of 12263)
# [INFO][2021/12/08 12:53:12 PM]  - Fates.TERMINATE_BORDER: 115 (of 362)
# [INFO][2021/12/08 12:53:12 PM]  - Fates.TERMINATE_BACK: 531 (of 748)
# [INFO][2021/12/08 12:53:13 PM]  - Fates.TERMINATE_LAZY: 2881 (of 11575)
# [INFO][2021/12/08 12:53:13 PM]  - TOTAL: 50044 hypotheses
# [INFO][2021/12/08 12:53:13 PM] Completed optimization with 7583 tracks
# [INFO][2021/12/08 12:53:14 PM] Ending BayesianTracker session
# [INFO][2021/12/08 12:53:15 PM] Loaded btrack: C:\Users\kmkedz\AppData\Roaming\Python\Python37\site-packages\btrack\libs\libtracker.DLL
# [INFO][2021/12/08 12:53:15 PM] btrack (v0.4.2) library imported
# [INFO][2021/12/08 12:53:15 PM] Setting max XYZ search radius to: 100
# [INFO][2021/12/08 12:53:15 PM] Starting BayesianTracker session
# [INFO][2021/12/08 12:53:15 PM] Loading configuration file: Z:\Sonja\210910_endo_meso_52\code\libraries\cell_config.json
# [INFO][2021/12/08 12:53:15 PM] Loading motion model: b'cell_motion'
# [INFO][2021/12/08 12:53:15 PM] Setting Bayesian update method to: BayesianUpdates.APPROXIMATE
# [INFO][2021/12/08 12:53:15 PM] Setting max XYZ search radius to: 200
# [INFO][2021/12/08 12:53:15 PM] Objects are of type: <class 'pandas.core.frame.DataFrame'>
# [INFO][2021/12/08 12:53:16 PM] Set volume to ((0, 2048), (0, 2048), (-100000.0, 100000.0))
# [INFO][2021/12/08 12:53:16 PM] Starting tracking...
# [INFO][2021/12/08 12:53:16 PM] Tracking objects in frames 0 to 99 (of 774)...
# [INFO][2021/12/08 12:53:18 PM]  - Timing (Bayesian updates: 6.00ms, Linking: 2.00ms)
# [INFO][2021/12/08 12:53:18 PM]  - Probabilities (Link: 0.99975, Lost: 1.00000)
# [INFO][2021/12/08 12:53:18 PM]  - Stats (Active: 411, Lost: 37158, Conflicts resolved: 6163)
# [INFO][2021/12/08 12:53:18 PM] Tracking objects in frames 100 to 199 (of 774)...
# [INFO][2021/12/08 12:53:18 PM]  - Timing (Bayesian updates: 1.00ms, Linking: 0.00ms)
# [INFO][2021/12/08 12:53:18 PM]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2021/12/08 12:53:18 PM]  - Stats (Active: 54, Lost: 48409, Conflicts resolved: 6879)
# [INFO][2021/12/08 12:53:18 PM] Tracking objects in frames 200 to 299 (of 774)...
# [INFO][2021/12/08 12:53:18 PM]  - Timing (Bayesian updates: 0.00ms, Linking: 0.00ms)
# [INFO][2021/12/08 12:53:18 PM]  - Probabilities (Link: 0.99997, Lost: 0.99995)
# [INFO][2021/12/08 12:53:18 PM] SUCCESS.
# [INFO][2021/12/08 12:53:18 PM]  - Found 8687 tracks in 774 frames (in 0.0s)
# [INFO][2021/12/08 12:53:18 PM]  - Inserted 7629 dummy objects to fill tracking gaps
# [INFO][2021/12/08 12:53:18 PM] Loading hypothesis model: cell_hypothesis
# [INFO][2021/12/08 12:53:18 PM] Calculating hypotheses (relax: True)...
# [INFO][2021/12/08 12:53:18 PM] Setting up constraints matrix for global optimisation...
# [INFO][2021/12/08 12:53:20 PM] Optimizing...
# [INFO][2021/12/08 12:53:25 PM] Optimization complete. (Solution: optimal)
# [INFO][2021/12/08 12:53:25 PM]  - Fates.FALSE_POSITIVE: 4204 (of 8687)
# [INFO][2021/12/08 12:53:25 PM]  - Fates.LINK: 2372 (of 4463)
# [INFO][2021/12/08 12:53:25 PM]  - Fates.DIVIDE: 207 (of 752)
# [INFO][2021/12/08 12:53:25 PM]  - Fates.INITIALIZE_BORDER: 119 (of 439)
# [INFO][2021/12/08 12:53:25 PM]  - Fates.INITIALIZE_LAZY: 1578 (of 8248)
# [INFO][2021/12/08 12:53:25 PM]  - Fates.TERMINATE_BORDER: 111 (of 438)
# [INFO][2021/12/08 12:53:25 PM]  - Fates.TERMINATE_BACK: 14 (of 36)
# [INFO][2021/12/08 12:53:25 PM]  - Fates.TERMINATE_LAZY: 1779 (of 8213)
# [INFO][2021/12/08 12:53:25 PM]  - TOTAL: 31276 hypotheses
# [INFO][2021/12/08 12:53:25 PM] Completed optimization with 6315 tracks
# [INFO][2021/12/08 12:53:26 PM] Ending BayesianTracker session
# [INFO][2021/12/08 12:53:26 PM] Loaded btrack: C:\Users\kmkedz\AppData\Roaming\Python\Python37\site-packages\btrack\libs\libtracker.DLL
# [INFO][2021/12/08 12:53:26 PM] btrack (v0.4.2) library imported
# [INFO][2021/12/08 12:53:26 PM] Setting max XYZ search radius to: 100
# [INFO][2021/12/08 12:53:26 PM] Starting BayesianTracker session
# [INFO][2021/12/08 12:53:26 PM] Loading configuration file: Z:\Sonja\210910_endo_meso_52\code\libraries\cell_config.json
# [INFO][2021/12/08 12:53:26 PM] Loading motion model: b'cell_motion'
# [INFO][2021/12/08 12:53:26 PM] Setting Bayesian update method to: BayesianUpdates.APPROXIMATE
# [INFO][2021/12/08 12:53:26 PM] Setting max XYZ search radius to: 200
# [INFO][2021/12/08 12:53:26 PM] Objects are of type: <class 'pandas.core.frame.DataFrame'>
# [INFO][2021/12/08 12:53:26 PM] Set volume to ((0, 2048), (0, 2048), (-100000.0, 100000.0))
# [INFO][2021/12/08 12:53:26 PM] Starting tracking...
# [INFO][2021/12/08 12:53:26 PM] Tracking objects in frames 0 to 99 (of 1033)...
# [INFO][2021/12/08 12:53:26 PM]  - Timing (Bayesian updates: 1.00ms, Linking: 0.00ms)
# [INFO][2021/12/08 12:53:26 PM]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2021/12/08 12:53:26 PM]  - Stats (Active: 95, Lost: 4183, Conflicts resolved: 148)
# [INFO][2021/12/08 12:53:26 PM] Tracking objects in frames 100 to 199 (of 1033)...
# [INFO][2021/12/08 12:53:27 PM]  - Timing (Bayesian updates: 2.00ms, Linking: 2.00ms)
# [INFO][2021/12/08 12:53:27 PM]  - Probabilities (Link: 0.99997, Lost: 1.00000)
# [INFO][2021/12/08 12:53:27 PM]  - Stats (Active: 259, Lost: 15147, Conflicts resolved: 765)
# [INFO][2021/12/08 12:53:27 PM] Tracking objects in frames 200 to 299 (of 1033)...
# [INFO][2021/12/08 12:53:27 PM]  - Timing (Bayesian updates: 9.00ms, Linking: 2.00ms)
# [INFO][2021/12/08 12:53:27 PM]  - Probabilities (Link: 0.23695, Lost: 1.00000)
# [INFO][2021/12/08 12:53:27 PM] SUCCESS.
# [INFO][2021/12/08 12:53:27 PM]  - Found 4344 tracks in 1033 frames (in 0.0s)
# [INFO][2021/12/08 12:53:27 PM]  - Inserted 4485 dummy objects to fill tracking gaps
# [INFO][2021/12/08 12:53:27 PM] Loading hypothesis model: cell_hypothesis
# [INFO][2021/12/08 12:53:27 PM] Calculating hypotheses (relax: True)...
# [INFO][2021/12/08 12:53:27 PM] Setting up constraints matrix for global optimisation...
# [INFO][2021/12/08 12:53:27 PM] Optimizing...
# [INFO][2021/12/08 12:53:28 PM] Optimization complete. (Solution: optimal)
# [INFO][2021/12/08 12:53:28 PM]  - Fates.FALSE_POSITIVE: 2628 (of 4344)
# [INFO][2021/12/08 12:53:28 PM]  - Fates.LINK: 656 (of 983)
# [INFO][2021/12/08 12:53:28 PM]  - Fates.DIVIDE: 29 (of 81)
# [INFO][2021/12/08 12:53:28 PM]  - Fates.INITIALIZE_BORDER: 79 (of 279)
# [INFO][2021/12/08 12:53:28 PM]  - Fates.INITIALIZE_LAZY: 923 (of 4065)
# [INFO][2021/12/08 12:53:28 PM]  - Fates.TERMINATE_BORDER: 67 (of 264)
# [INFO][2021/12/08 12:53:28 PM]  - Fates.TERMINATE_BACK: 299 (of 429)
# [INFO][2021/12/08 12:53:28 PM]  - Fates.TERMINATE_LAZY: 665 (of 3651)
# [INFO][2021/12/08 12:53:28 PM]  - TOTAL: 14096 hypotheses
# [INFO][2021/12/08 12:53:28 PM] Completed optimization with 3688 tracks
# [INFO][2021/12/08 12:53:29 PM] Ending BayesianTracker session

# %% [markdown]
# ## Merging objects and tracking information

# %%
len(trackDataAll)
# Out:
# 263046

# %%
allData = pd.merge(left=data_df,right=trackDataAll,left_on=['centroid-0','centroid-1','t'],right_on=['x','y','t'],how='left')

# %%
print(f'Number of all objects: {len(allData)}')
# Out:
# Number of all objects: 223543

# %%
allData.head()
# Out:
#    label  area  centroid-0   centroid-1  orientation  major_axis_length  \
# 0      7  1338   37.109118  1727.743647    -0.369780          54.154746
# 1      8  1373   40.700655   604.683176    -1.136684          48.529689
# 2      9  1246   42.348315   389.571429     0.927465          53.063363
# 3     10  1119   47.858803   847.581769     1.024182          53.249772
# 4     11  1532   49.441906  1182.359661    -0.666132          57.934427
#
#    minor_axis_length  bbox-0  bbox-1  bbox-2  ...  mean_intensity-0_ring  \
# 0          32.189471       8    1708      62  ...             224.069307
# 1          36.937616      22     579      63  ...             226.690815
# 2          30.931133      24     364      64  ...             233.304795
# 3          27.858318      30     826      67  ...             241.000000
# 4          34.102222      23    1159      74  ...             234.783175
#
#   mean_intensity-1_ring  size_x  size_y track_id   x   y  parent  generation  \
# 0            145.935644    2048    2048      NaN NaN NaN     NaN         NaN
# 1            141.375162    2048    2048      NaN NaN NaN     NaN         NaN
# 2            141.203767    2048    2048      NaN NaN NaN     NaN         NaN
# 3            147.360324    2048    2048      NaN NaN NaN     NaN         NaN
# 4            146.752370    2048    2048      NaN NaN NaN     NaN         NaN
#
#    root
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 28 columns]

# %%
allData.columns
# Out:
# Index(['label', 'area', 'centroid-0', 'centroid-1', 'orientation',
#        'major_axis_length', 'minor_axis_length', 'bbox-0', 'bbox-1', 'bbox-2',
#        'bbox-3', 'image', 'mean_intensity-0_nuc', 'mean_intensity-1_nuc',
#        'file', 't', 'centroid-0_ring', 'centroid-1_ring',
#        'mean_intensity-0_ring', 'mean_intensity-1_ring', 'size_x', 'size_y',
#        'track_id', 'x', 'y', 'parent', 'generation', 'root'],
#       dtype='object')

# %% [markdown]
# ## Define promising tracks

# %%
allData['accepted'] = False
allData['rejected'] = False
allData['promise'] = False

# mark tracks longer than 100 as promising
tracks_set = set(allData.track_id)

for track in tracks_set:
    
    track_len = np.sum(allData.track_id==track)
    
    if (track_len > 50):
        
        allData.loc[allData.track_id==track,'promise'] = True

# %%
# save df
allData.to_pickle(os.path.join(df_dir,df_name))
allData.to_csv(os.path.join(df_dir,df_name.replace('pkl','csv')),index=False)
